# %% [markdown]
# # IMPORT LIBRARIES AND DATABASE AND COLLECTIONS

# %%
import pymongo
import schedule
import time
from datetime import datetime
import redis
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import sys
from fastapi import FastAPI

# Establish connection to MongoDB
client = pymongo.MongoClient("mongodb://localhost:27017/")

# Establish connection to Redis using Docker container host
redis_client = redis.StrictRedis(host='localhost', port=6379, db=0, decode_responses=True)

# Access the database
db = client['yelp']

# Access the collections
review_collection = db['review']
business_collection = db['business']
admin_collection = db['admin']

# %% [markdown]
# # AUFGABE 2
# ### SEND EMAIL NOTIFICATION TO ADMIN IF THRESHOLD IS EXCEEDED

# %%
# Get the business name as input
username_input = input("Enter admin username: ")
password_input = input("Enter admin password: ")
print("Checking for new low-rated reviews...")

def send_email(receiver_email, subject, body):
    sender_email = "eunicelimuria@gmail.com"  # Replace with your email
    sender_password = "qtyo xhpj mpuk znjt"   # Replace with your email password

    message = MIMEMultipart()
    message["From"] = sender_email
    message["To"] = receiver_email
    message["Subject"] = subject

    message.attach(MIMEText(body, "plain"))

    with smtplib.SMTP("smtp.gmail.com", 587) as server:
        server.starttls()
        server.login(sender_email, sender_password)
        server.sendmail(sender_email, receiver_email, message.as_string())


previous_review_ids = set()  # Storing previous review IDs

def notify_low_rating_reviews(username, password):
    existing_admin = admin_collection.find_one({"admin_username": username})
    if existing_admin is not None:
        pass
    else:
        raise ValueError("Wrong username. Please enter the right username and password.")

    threshold_percentage = admin_collection.find_one({"admin_username": username})['threshold_percentage']
    last_n_reviews = admin_collection.find_one({"admin_username": username})['last_n_reviews']
    business_id = admin_collection.find_one({"admin_username": username})['business_id']
    business_name = business_collection.find_one({"business_id": business_id})['name']

    if admin_collection.find_one({"admin_username": username})['admin_password'] != password:
        raise ValueError("Wrong password. Please enter the right username and password.")

    current_date = datetime.now().strftime("%Y-%m-%d %H:%M:%S")


    admin = admin_collection.find_one({"business_id": business_id})
    if not admin:
        return "Admin not found"
    admin_email = admin['admin_email']

    # Find the last 'n' reviews for the given business_id based on the "date" field
    recent_reviews = list(review_collection.find(
        {"business_id": business_id}
    ).sort([("date", -1)]).limit(last_n_reviews))

    print("Recent reviews:")
    for review in recent_reviews:
        print(f"Review: {review['_id']} - Stars: {review['stars']} - Date: {review['date']}")

    # Get the set of current review IDs
    current_review_ids = {review['_id'] for review in recent_reviews}

    # Check if there are new reviews by comparing review IDs
    new_reviews = current_review_ids - previous_review_ids

    # Update previous_review_ids with the current review IDs
    previous_review_ids.update(current_review_ids)

    if new_reviews:  # If there are new reviews, proceed to send an email
        # Calculate the percentage of reviews with stars 1 or 2 out of the last 'n' reviews
        low_rating_count = sum(1 for review in recent_reviews if review['stars'] in [1, 2])
        total_reviews = len(recent_reviews)
        percentage = (low_rating_count / total_reviews) * 100 if total_reviews > 0 else 0

        # Notify if the threshold percentage is exceeded
        if percentage >= threshold_percentage:
            redis_channel = "admin_negative_reviews_channel"
            redis_message = f"Business: {business_name} received {percentage} negative reviews"
            redis_client.publish(redis_channel, redis_message)

            # Send email notification
            email_subject = "Negative Reviews Notification"
            email_body = f"Dear {business_name} Admin,\n\nYour business has received {percentage:.2f}% negative reviews of the last {last_n_reviews} reviews.\n\nChecked on {current_date}\n\nSincerely,\nYelp Review System."
            send_email(admin_email, email_subject, email_body)

            return f"Checked on {current_date}. Threshold exceeded: {percentage:.2f}% of the last {last_n_reviews} reviews for '{business_name}' have low ratings."

    return None


def job():
    try:
        result = notify_low_rating_reviews(username_input, password_input)
        if result:
            print(result)
    except ValueError as err:
        print(err)
        sys.exit()

# Schedule the job to run every second (adjust as needed)
schedule.every(1).second.do(job)

# Run the job initially
job()

# Keep the script running
while True:
    schedule.run_pending()
    time.sleep(30)
# Out:
# Checking for new low-rated reviews...
# Recent reviews:
# Review: 656b239c8895f3b51c4f684d - Stars: 5 - Date: 2015-03-16 03:43:08
# Review: 656b23a38895f3b51c5079cd - Stars: 5 - Date: 2013-03-05 18:45:07
# Review: 656b23928895f3b51c4e06d9 - Stars: 5 - Date: 2013-03-01 06:11:05
# Review: 656b239a8895f3b51c4f3121 - Stars: 4 - Date: 2013-01-17 00:05:43
# Review: 656b23c08895f3b51c53bf87 - Stars: 5 - Date: 2012-08-09 20:43:27
# Recent reviews:
# Review: 656b239c8895f3b51c4f684d - Stars: 5 - Date: 2015-03-16 03:43:08
# Review: 656b23a38895f3b51c5079cd - Stars: 5 - Date: 2013-03-05 18:45:07
# Review: 656b23928895f3b51c4e06d9 - Stars: 5 - Date: 2013-03-01 06:11:05
# Review: 656b239a8895f3b51c4f3121 - Stars: 4 - Date: 2013-01-17 00:05:43
# Review: 656b23c08895f3b51c53bf87 - Stars: 5 - Date: 2012-08-09 20:43:27

# %% [markdown]
# ### SEND EMAIL FOR ALL ADMINS

# %%
# Storing previous review IDs
previous_review_ids = set()

def email_exists(email):
    existing_admin = admin_collection.find_one({"admin_email": email})
    return existing_admin is not None

def business_exists(business_name):
    existing_business = admin_collection.find_one({"business_name": business_name})
    return existing_business is not None

def send_email(receiver_email, subject, body):
    sender_email = "eunicelimuria@gmail.com"  # Replace with your email
    sender_password = "qtyo xhpj mpuk znjt"   # Replace with your email password

    message = MIMEMultipart()
    message["From"] = sender_email
    message["To"] = receiver_email
    message["Subject"] = subject

    message.attach(MIMEText(body, "plain"))

    with smtplib.SMTP("smtp.gmail.com", 587) as server:
        server.starttls()
        server.login(sender_email, sender_password)
        server.sendmail(sender_email, receiver_email, message.as_string())

def notify_low_rating_reviews(username, password, threshold_percentage, last_n_reviews, business_id, admin_email):
    if admin_collection.find_one({"admin_username": username})['admin_password'] != password:
        raise ValueError("Wrong password. Please enter the right username and password.")
    
    threshold_percentage = admin_collection.find_one({"admin_username": username})['threshold_percentage']
    last_n_reviews = admin_collection.find_one({"admin_username": username})['last_n_reviews']
    business_id = admin_collection.find_one({"admin_username": username})['business_id']
    business_name = business_collection.find_one({"business_id": business_id})['name']

    current_date = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    admin = admin_collection.find_one({"business_id": business_id})
    if not admin:
        return "Admin not found"
    
    # Find the last 'n' reviews for the given business_id based on the "date" field
    recent_reviews = list(review_collection.find(
        {"business_id": business_id}
    ).sort([("date", -1)]).limit(last_n_reviews))

    print(f"Recent reviews for Admin {username}:")
    for review in recent_reviews:
        print(f"Review: {review['_id']} - Stars: {review['stars']} - Date: {review['date']}")

    # Get the set of current review IDs
    current_review_ids = {review['_id'] for review in recent_reviews}

    # Check if there are new reviews by comparing review IDs
    new_reviews = current_review_ids - previous_review_ids

    # Update previous_review_ids with the current review IDs
    previous_review_ids.update(current_review_ids)

    admin_name = admin['admin_name']

    if new_reviews:  # If there are new reviews, proceed to send an email
        # Calculate the percentage of reviews with stars 1 or 2 out of the last 'n' reviews
        low_rating_count = sum(1 for review in recent_reviews if review['stars'] in [1, 2])
        total_reviews = len(recent_reviews)
        percentage = (low_rating_count / total_reviews) * 100 if total_reviews > 0 else 0

        # Notify if the threshold percentage is exceeded
        if percentage >= threshold_percentage:
            redis_channel = "admin_negative_reviews_channel"
            redis_message = f"Business: {business_name} received {percentage} negative reviews"
            redis_client.publish(redis_channel, redis_message)

            # Send email notification
            email_subject = "Negative Reviews Notification"
            email_body = f"Dear {admin_name},\n\nYour business '{business_name}' has received {percentage:.2f}% negative reviews of the last {last_n_reviews} reviews.\n\nChecked on {current_date}\n\nSincerely,\nYelp Review System."
            send_email(admin_email, email_subject, email_body)

            return f"Checked on {current_date}. Threshold exceeded: {percentage:.2f}% of the last {last_n_reviews} reviews for '{business_name}' have low ratings."

    return None

def job():
    try:
        admins = admin_collection.find({})
        for admin in admins:
            username = admin['admin_username']
            password = admin['admin_password']
            threshold_percentage = admin['threshold_percentage']
            last_n_reviews = admin['last_n_reviews']
            business_id = admin['business_id']
            admin_email = admin['admin_email']

            result = notify_low_rating_reviews(username, password, threshold_percentage, last_n_reviews, business_id, admin_email)
            if result:
                print(result)
    except ValueError as err:
        print(err)
        sys.exit()

# Schedule the job to run every second (adjust as needed)
schedule.every(1).second.do(job)

# Run the job initially
job()

# Keep the script running
while True:
    schedule.run_pending()
    time.sleep(30)
# Out:
# Recent reviews for Admin target_blvd5255:
# Review: 280458dc-3c0b-4910-840b-6aecee6c792c - Stars: 1 - Date: 2023-12-05 08:38:18
# Review: 656b23c78895f3b51c54a7fc - Stars: 4 - Date: 2020-12-02 02:50:27
# Review: 656b23ab8895f3b51c518f20 - Stars: 3 - Date: 2019-04-13 09:01:50
# Review: 656b23d48895f3b51c56143c - Stars: 3 - Date: 2018-12-21 09:20:13
# Review: 656b23a58895f3b51c50b6f0 - Stars: 1 - Date: 2018-11-12 04:27:49
# Review: 656b23a88895f3b51c511729 - Stars: 5 - Date: 2018-09-20 02:32:01
# Review: 656b23ca8895f3b51c54fa21 - Stars: 5 - Date: 2018-09-14 00:38:39
# Review: 656b23a28895f3b51c504152 - Stars: 1 - Date: 2017-12-01 19:58:25
# Review: 656b23988895f3b51c4ed5d5 - Stars: 4 - Date: 2017-08-14 23:34:39
# Review: 656b23858895f3b51c4c34be - Stars: 4 - Date: 2017-02-19 15:11:22
# Checked on 2023-12-05 20:18:19. Threshold exceeded: 30.00% of the last 10 reviews for 'Target' have low ratings.
# Recent reviews for Admin abby:
# Review: 656b239c8895f3b51c4f684d - Stars: 5 - Date: 2015-03-16 03:43:08
# Review: 656b23a38895f3b51c5079cd - Stars: 5 - Date: 2013-03-05 18:45:07
# Review: 656b23928895f3b51c4e06d9 - Stars: 5 - Date: 2013-03-01 06:11:05
# Review: 656b239a8895f3b51c4f3121 - Stars: 4 - Date: 2013-01-17 00:05:43
# Review: 656b23c08895f3b51c53bf87 - Stars: 5 - Date: 2012-08-09 20:43:27
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\vae.tiolamon\Documents\DHBW 3. Semester\Datenbanken\DBneu\tobesubmitted_notification.ipynb Cell 6 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#W5sZmlsZQ%3D%3D?line=102'>103</a> schedule.every(1).second.do(job)
#     <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#W5sZmlsZQ%3D%3D?line=104'>105</a> # Run the job initially
# --> <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#W5sZmlsZQ%3D%3D?line=105'>106</a> job()
#     <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#W5sZmlsZQ%3D%3D?line=107'>108</a> # Keep the script running
#     <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#W5sZmlsZQ%3D%3D?line=108'>109</a> while True:
#
# c:\Users\vae.tiolamon\Documents\DHBW 3. Semester\Datenbanken\DBneu\tobesubmitted_notification.ipynb Cell 6 line 9
#      <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#W5sZmlsZQ%3D%3D?line=91'>92</a> business_id = admin['business_id']
#      <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#W5sZmlsZQ%3D%3D?line=92'>93</a> admin_email = admin['admin_email']
# ---> <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#W5sZmlsZQ%3D%3D?line=94'>95</a> result = notify_low_rating_reviews(username, password, threshold_percentage, last_n_reviews, business_id, admin_email)
#      <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#W5sZmlsZQ%3D%3D?line=95'>96</a> if result:
#      <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#W5sZmlsZQ%3D%3D?line=96'>97</a>     print(result)
#
# c:\Users\vae.tiolamon\Documents\DHBW 3. Semester\Datenbanken\DBneu\tobesubmitted_notification.ipynb Cell 6 line 4
#      <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#W5sZmlsZQ%3D%3D?line=40'>41</a>     return "Admin not found"
#      <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#W5sZmlsZQ%3D%3D?line=42'>43</a> # Find the last 'n' reviews for the given business_id based on the "date" field
# ---> <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#W5sZmlsZQ%3D%3D?line=43'>44</a> recent_reviews = list(review_collection.find(
#      <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#W5sZmlsZQ%3D%3D?line=44'>45</a>     {"business_id": business_id}
#      <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#W5sZmlsZQ%3D%3D?line=45'>46</a> ).sort([("date", -1)]).limit(last_n_reviews))
#      <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#W5sZmlsZQ%3D%3D?line=47'>48</a> print(f"Recent reviews for Admin {username}:")
#      <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#W5sZmlsZQ%3D%3D?line=48'>49</a> for review in recent_reviews:
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\cursor.py:1264, in Cursor.next(self)
#    1262 if self.__empty:
#    1263     raise StopIteration
# -> 1264 if len(self.__data) or self._refresh():
#    1265     return self.__data.popleft()
#    1266 else:
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\cursor.py:1181, in Cursor._refresh(self)
#    1159         raise InvalidOperation(
#    1160             "Passing a 'hint' is required when using the min/max query"
#    1161             " option to ensure the query utilizes the correct index"
#    1162         )
#    1163     q = self._query_class(
#    1164         self.__query_flags,
#    1165         self.__collection.database.name,
#    (...)
#    1179         self.__exhaust,
#    1180     )
# -> 1181     self.__send_message(q)
#    1182 elif self.__id:  # Get More
#    1183     if self.__limit:
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\cursor.py:1060, in Cursor.__send_message(self, operation)
#    1057     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1059 try:
# -> 1060     response = client._run_operation(
#    1061         operation, self._unpack_response, address=self.__address
#    1062     )
#    1063 except OperationFailure as exc:
#    1064     if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#    1065         # Don't send killCursors because the cursor is already closed.
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1394, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1389     operation.reset()  # Reset op in case of retry.
#    1390     return server.run_operation(
#    1391         conn, operation, read_preference, self._event_listeners, unpack_res
#    1392     )
# -> 1394 return self._retryable_read(
#    1395     _cmd,
#    1396     operation.read_preference,
#    1397     operation.session,
#    1398     address=address,
#    1399     retryable=isinstance(operation, message._Query),
#    1400 )
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1492, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1487 # Ensure that the client supports retrying on reads and there is no session in
#    1488 # transaction, otherwise, we will not support retry behavior for this call.
#    1489 retryable = bool(
#    1490     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1491 )
# -> 1492 return self._retry_internal(
#    1493     func,
#    1494     session,
#    1495     None,
#    1496     is_read=True,
#    1497     address=address,
#    1498     read_pref=read_pref,
#    1499     retryable=retryable,
#    1500 )
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1462, in MongoClient._retry_internal(self, func, session, bulk, is_read, address, read_pref, retryable)
#    1428 @_csot.apply
#    1429 def _retry_internal(
#    1430     self,
#    (...)
#    1437     retryable: bool = False,
#    1438 ) -> T:
#    1439     """Internal retryable helper for all client transactions.
#    1440
#    1441     :Parameters:
#    (...)
#    1451       Output of the calling func()
#    1452     """
#    1453     return _ClientConnectionRetryable(
#    1454         mongo_client=self,
#    1455         func=func,
#    1456         bulk=bulk,
#    1457         is_read=is_read,
#    1458         session=session,
#    1459         read_pref=read_pref,
#    1460         address=address,
#    1461         retryable=retryable,
# -> 1462     ).run()
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:2315, in _ClientConnectionRetryable.run(self)
#    2313 self._check_last_error(check_csot=True)
#    2314 try:
# -> 2315     return self._read() if self._is_read else self._write()
#    2316 except ServerSelectionTimeoutError:
#    2317     # The application may think the write was never attempted
#    2318     # if we raise ServerSelectionTimeoutError on the retry
#    2319     # attempt. Raise the original exception instead.
#    2320     self._check_last_error()
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:2445, in _ClientConnectionRetryable._read(self)
#    2443 if self._retrying and not self._retryable:
#    2444     self._check_last_error()
# -> 2445 return self._func(self._session, self._server, conn, read_pref)
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1390, in MongoClient._run_operation.<locals>._cmd(_session, server, conn, read_preference)
#    1383 def _cmd(
#    1384     _session: Optional[ClientSession],
#    1385     server: Server,
#    1386     conn: Connection,
#    1387     read_preference: _ServerMode,
#    1388 ) -> Response:
#    1389     operation.reset()  # Reset op in case of retry.
# -> 1390     return server.run_operation(
#    1391         conn, operation, read_preference, self._event_listeners, unpack_res
#    1392     )
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\helpers.py:322, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     319 from pymongo.pool import Connection
#     321 try:
# --> 322     return func(*args, **kwargs)
#     323 except OperationFailure as exc:
#     324     if no_reauth:
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\server.py:148, in Server.run_operation(self, conn, operation, read_preference, listeners, unpack_res)
#     146 else:
#     147     conn.send_message(data, max_doc_size)
# --> 148     reply = conn.receive_message(request_id)
#     150 # Unpack and check for command errors.
#     151 if use_cmd:
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1022, in Connection.receive_message(self, request_id)
#    1020     return receive_message(self, request_id, self.max_message_size)
#    1021 except BaseException as error:
# -> 1022     self._raise_connection_failure(error)
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1020, in Connection.receive_message(self, request_id)
#    1015 """Receive a raw BSON message or raise ConnectionFailure.
#    1016
#    1017 If any exception is raised, the socket is closed.
#    1018 """
#    1019 try:
# -> 1020     return receive_message(self, request_id, self.max_message_size)
#    1021 except BaseException as error:
#    1022     self._raise_connection_failure(error)
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\network.py:257, in receive_message(conn, request_id, max_message_size)
#     255         deadline = None
#     256 # Ignore the response's request id.
# --> 257 length, _, response_to, op_code = _UNPACK_HEADER(_receive_data_on_socket(conn, 16, deadline))
#     258 # No request_id for exhaust cursor "getMore".
#     259 if request_id is not None:
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\network.py:340, in _receive_data_on_socket(conn, length, deadline)
#     338     if _csot.get_timeout() and deadline is not None:
#     339         conn.set_conn_timeout(max(deadline - time.monotonic(), 0))
# --> 340     chunk_length = conn.conn.recv_into(mv[bytes_read:])
#     341 except BLOCKING_IO_ERRORS:
#     342     raise socket.timeout("timed out") from None
#
# KeyboardInterrupt:

# %%
app = FastAPI()

# Storing previous review IDs
previous_review_ids = set()

def email_exists(email):
    existing_admin = admin_collection.find_one({"admin_email": email})
    return existing_admin is not None

def business_exists(business_name):
    existing_business = admin_collection.find_one({"business_name": business_name})
    return existing_business is not None

def send_email(receiver_email, subject, body):
    sender_email = "eunicelimuria@gmail.com"  # Replace with your email
    sender_password = "qtyo xhpj mpuk znjt"   # Replace with your email password

    message = MIMEMultipart()
    message["From"] = sender_email
    message["To"] = receiver_email
    message["Subject"] = subject

    message.attach(MIMEText(body, "plain"))

    with smtplib.SMTP("smtp.gmail.com", 587) as server:
        server.starttls()
        server.login(sender_email, sender_password)
        server.sendmail(sender_email, receiver_email, message.as_string())

def notify_low_rating_reviews(username, password, threshold_percentage, last_n_reviews, business_id, admin_email):
    if admin_collection.find_one({"admin_username": username})['admin_password'] != password:
        raise ValueError("Wrong password. Please enter the right username and password.")
    
    threshold_percentage = admin_collection.find_one({"admin_username": username})['threshold_percentage']
    last_n_reviews = admin_collection.find_one({"admin_username": username})['last_n_reviews']
    business_id = admin_collection.find_one({"admin_username": username})['business_id']
    business_name = business_collection.find_one({"business_id": business_id})['name']

    current_date = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    admin = admin_collection.find_one({"business_id": business_id})
    if not admin:
        return "Admin not found"
    
    # Find the last 'n' reviews for the given business_id based on the "date" field
    recent_reviews = list(review_collection.find(
        {"business_id": business_id}
    ).sort([("date", -1)]).limit(last_n_reviews))

    print(f"Recent reviews for Admin {username}:")
    for review in recent_reviews:
        print(f"Review: {review['_id']} - Stars: {review['stars']} - Date: {review['date']}")

    # Get the set of current review IDs
    current_review_ids = {review['_id'] for review in recent_reviews}

    # Check if there are new reviews by comparing review IDs
    new_reviews = current_review_ids - previous_review_ids

    # Update previous_review_ids with the current review IDs
    previous_review_ids.update(current_review_ids)

    admin_name = admin['admin_name']

    if new_reviews:  # If there are new reviews, proceed to send an email
        # Calculate the percentage of reviews with stars 1 or 2 out of the last 'n' reviews
        low_rating_count = sum(1 for review in recent_reviews if review['stars'] in [1, 2])
        total_reviews = len(recent_reviews)
        percentage = (low_rating_count / total_reviews) * 100 if total_reviews > 0 else 0

        # Notify if the threshold percentage is exceeded
        if percentage >= threshold_percentage:
            redis_channel = "admin_negative_reviews_channel"
            redis_message = f"Business: {business_name} received {percentage} negative reviews"
            redis_client.publish(redis_channel, redis_message)

            # Send email notification
            email_subject = "Negative Reviews Notification"
            email_body = f"Dear {admin_name},\n\nYour business '{business_name}' has received {percentage:.2f}% negative reviews of the last {last_n_reviews} reviews.\n\nChecked on {current_date}\n\nSincerely,\nYelp Review System."
            send_email(admin_email, email_subject, email_body)

            return f"Checked on {current_date}. Threshold exceeded: {percentage:.2f}% of the last {last_n_reviews} reviews for '{business_name}' have low ratings."

    return None


#@app.get("/check_reviews")
def job():
    try:
        admins = admin_collection.find({})
        for admin in admins:
            username = admin['admin_username']
            password = admin['admin_password']
            threshold_percentage = admin['threshold_percentage']
            last_n_reviews = admin['last_n_reviews']
            business_id = admin['business_id']
            admin_email = admin['admin_email']

            result = notify_low_rating_reviews(username, password, threshold_percentage, last_n_reviews, business_id, admin_email)
            if result:
                print(result)
        
        return {"message": "Review check completed."}
    except ValueError as err:
        print(err)
        sys.exit()

# Schedule the job to run every second (adjust as needed)
schedule.every(1).second.do(job)

# Run the job initially
job()

# Keep the script running
while True:
    schedule.run_pending()
    time.sleep(30)
# Out:
# Recent reviews for Admin target_blvd5255:
# Review: 280458dc-3c0b-4910-840b-6aecee6c792c - Stars: 1 - Date: 2023-12-05 08:38:18
# Review: 656b23c78895f3b51c54a7fc - Stars: 4 - Date: 2020-12-02 02:50:27
# Review: 656b23ab8895f3b51c518f20 - Stars: 3 - Date: 2019-04-13 09:01:50
# Review: 656b23d48895f3b51c56143c - Stars: 3 - Date: 2018-12-21 09:20:13
# Review: 656b23a58895f3b51c50b6f0 - Stars: 1 - Date: 2018-11-12 04:27:49
# Review: 656b23a88895f3b51c511729 - Stars: 5 - Date: 2018-09-20 02:32:01
# Review: 656b23ca8895f3b51c54fa21 - Stars: 5 - Date: 2018-09-14 00:38:39
# Review: 656b23a28895f3b51c504152 - Stars: 1 - Date: 2017-12-01 19:58:25
# Review: 656b23988895f3b51c4ed5d5 - Stars: 4 - Date: 2017-08-14 23:34:39
# Review: 656b23858895f3b51c4c34be - Stars: 4 - Date: 2017-02-19 15:11:22
# Checked on 2023-12-05 20:19:30. Threshold exceeded: 30.00% of the last 10 reviews for 'Target' have low ratings.
# Recent reviews for Admin abby:
# Review: 656b239c8895f3b51c4f684d - Stars: 5 - Date: 2015-03-16 03:43:08
# Review: 656b23a38895f3b51c5079cd - Stars: 5 - Date: 2013-03-05 18:45:07
# Review: 656b23928895f3b51c4e06d9 - Stars: 5 - Date: 2013-03-01 06:11:05
# Review: 656b239a8895f3b51c4f3121 - Stars: 4 - Date: 2013-01-17 00:05:43
# Review: 656b23c08895f3b51c53bf87 - Stars: 5 - Date: 2012-08-09 20:43:27
# Recent reviews for Admin target_wyncote:
# Review: 656b23c38895f3b51c54264f - Stars: 3 - Date: 2021-11-24 14:41:13
# Review: 656b23c18895f3b51c53ea70 - Stars: 2 - Date: 2021-05-20 19:15:44
# Review: 656b23d78895f3b51c5672ac - Stars: 3 - Date: 2020-11-23 03:26:13
# Review: 656b23ba8895f3b51c53201c - Stars: 5 - Date: 2020-06-02 16:43:07
# Review: 656b23b08895f3b51c520d09 - Stars: 1 - Date: 2020-05-03 03:41:34
# Review: 656b23b68895f3b51c528fb2 - Stars: 3 - Date: 2019-11-03 01:40:12
# Review: 656b23be8895f3b51c5385de - Stars: 2 - Date: 2019-10-04 02:07:38
# Review: 656b23c98895f3b51c54e4ad - Stars: 1 - Date: 2019-04-13 19:18:07
# Review: 656b23bb8895f3b51c534088 - Stars: 1 - Date: 2019-04-08 21:03:08
# Review: 656b23ab8895f3b51c517da3 - Stars: 1 - Date: 2018-03-03 05:51:52
# Checked on 2023-12-05 20:19:52. Threshold exceeded: 60.00% of the last 10 reviews for 'Target' have low ratings.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\vae.tiolamon\Documents\DHBW 3. Semester\Datenbanken\DBneu\tobesubmitted_notification.ipynb Cell 7 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#X14sZmlsZQ%3D%3D?line=108'>109</a> schedule.every(1).second.do(job)
#     <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#X14sZmlsZQ%3D%3D?line=110'>111</a> # Run the job initially
# --> <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#X14sZmlsZQ%3D%3D?line=111'>112</a> job()
#     <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#X14sZmlsZQ%3D%3D?line=113'>114</a> # Keep the script running
#     <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#X14sZmlsZQ%3D%3D?line=114'>115</a> while True:
#
# c:\Users\vae.tiolamon\Documents\DHBW 3. Semester\Datenbanken\DBneu\tobesubmitted_notification.ipynb Cell 7 line 9
#      <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#X14sZmlsZQ%3D%3D?line=95'>96</a> business_id = admin['business_id']
#      <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#X14sZmlsZQ%3D%3D?line=96'>97</a> admin_email = admin['admin_email']
# ---> <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#X14sZmlsZQ%3D%3D?line=98'>99</a> result = notify_low_rating_reviews(username, password, threshold_percentage, last_n_reviews, business_id, admin_email)
#     <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#X14sZmlsZQ%3D%3D?line=99'>100</a> if result:
#     <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#X14sZmlsZQ%3D%3D?line=100'>101</a>     print(result)
#
# c:\Users\vae.tiolamon\Documents\DHBW 3. Semester\Datenbanken\DBneu\tobesubmitted_notification.ipynb Cell 7 line 4
#      <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#X14sZmlsZQ%3D%3D?line=42'>43</a>     return "Admin not found"
#      <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#X14sZmlsZQ%3D%3D?line=44'>45</a> # Find the last 'n' reviews for the given business_id based on the "date" field
# ---> <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#X14sZmlsZQ%3D%3D?line=45'>46</a> recent_reviews = list(review_collection.find(
#      <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#X14sZmlsZQ%3D%3D?line=46'>47</a>     {"business_id": business_id}
#      <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#X14sZmlsZQ%3D%3D?line=47'>48</a> ).sort([("date", -1)]).limit(last_n_reviews))
#      <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#X14sZmlsZQ%3D%3D?line=49'>50</a> print(f"Recent reviews for Admin {username}:")
#      <a href='vscode-notebook-cell:/c%3A/Users/vae.tiolamon/Documents/DHBW%203.%20Semester/Datenbanken/DBneu/tobesubmitted_notification.ipynb#X14sZmlsZQ%3D%3D?line=50'>51</a> for review in recent_reviews:
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\cursor.py:1264, in Cursor.next(self)
#    1262 if self.__empty:
#    1263     raise StopIteration
# -> 1264 if len(self.__data) or self._refresh():
#    1265     return self.__data.popleft()
#    1266 else:
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\cursor.py:1181, in Cursor._refresh(self)
#    1159         raise InvalidOperation(
#    1160             "Passing a 'hint' is required when using the min/max query"
#    1161             " option to ensure the query utilizes the correct index"
#    1162         )
#    1163     q = self._query_class(
#    1164         self.__query_flags,
#    1165         self.__collection.database.name,
#    (...)
#    1179         self.__exhaust,
#    1180     )
# -> 1181     self.__send_message(q)
#    1182 elif self.__id:  # Get More
#    1183     if self.__limit:
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\cursor.py:1060, in Cursor.__send_message(self, operation)
#    1057     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1059 try:
# -> 1060     response = client._run_operation(
#    1061         operation, self._unpack_response, address=self.__address
#    1062     )
#    1063 except OperationFailure as exc:
#    1064     if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#    1065         # Don't send killCursors because the cursor is already closed.
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1394, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1389     operation.reset()  # Reset op in case of retry.
#    1390     return server.run_operation(
#    1391         conn, operation, read_preference, self._event_listeners, unpack_res
#    1392     )
# -> 1394 return self._retryable_read(
#    1395     _cmd,
#    1396     operation.read_preference,
#    1397     operation.session,
#    1398     address=address,
#    1399     retryable=isinstance(operation, message._Query),
#    1400 )
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1492, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1487 # Ensure that the client supports retrying on reads and there is no session in
#    1488 # transaction, otherwise, we will not support retry behavior for this call.
#    1489 retryable = bool(
#    1490     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1491 )
# -> 1492 return self._retry_internal(
#    1493     func,
#    1494     session,
#    1495     None,
#    1496     is_read=True,
#    1497     address=address,
#    1498     read_pref=read_pref,
#    1499     retryable=retryable,
#    1500 )
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1462, in MongoClient._retry_internal(self, func, session, bulk, is_read, address, read_pref, retryable)
#    1428 @_csot.apply
#    1429 def _retry_internal(
#    1430     self,
#    (...)
#    1437     retryable: bool = False,
#    1438 ) -> T:
#    1439     """Internal retryable helper for all client transactions.
#    1440
#    1441     :Parameters:
#    (...)
#    1451       Output of the calling func()
#    1452     """
#    1453     return _ClientConnectionRetryable(
#    1454         mongo_client=self,
#    1455         func=func,
#    1456         bulk=bulk,
#    1457         is_read=is_read,
#    1458         session=session,
#    1459         read_pref=read_pref,
#    1460         address=address,
#    1461         retryable=retryable,
# -> 1462     ).run()
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:2315, in _ClientConnectionRetryable.run(self)
#    2313 self._check_last_error(check_csot=True)
#    2314 try:
# -> 2315     return self._read() if self._is_read else self._write()
#    2316 except ServerSelectionTimeoutError:
#    2317     # The application may think the write was never attempted
#    2318     # if we raise ServerSelectionTimeoutError on the retry
#    2319     # attempt. Raise the original exception instead.
#    2320     self._check_last_error()
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:2445, in _ClientConnectionRetryable._read(self)
#    2443 if self._retrying and not self._retryable:
#    2444     self._check_last_error()
# -> 2445 return self._func(self._session, self._server, conn, read_pref)
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1390, in MongoClient._run_operation.<locals>._cmd(_session, server, conn, read_preference)
#    1383 def _cmd(
#    1384     _session: Optional[ClientSession],
#    1385     server: Server,
#    1386     conn: Connection,
#    1387     read_preference: _ServerMode,
#    1388 ) -> Response:
#    1389     operation.reset()  # Reset op in case of retry.
# -> 1390     return server.run_operation(
#    1391         conn, operation, read_preference, self._event_listeners, unpack_res
#    1392     )
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\helpers.py:322, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     319 from pymongo.pool import Connection
#     321 try:
# --> 322     return func(*args, **kwargs)
#     323 except OperationFailure as exc:
#     324     if no_reauth:
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\server.py:148, in Server.run_operation(self, conn, operation, read_preference, listeners, unpack_res)
#     146 else:
#     147     conn.send_message(data, max_doc_size)
# --> 148     reply = conn.receive_message(request_id)
#     150 # Unpack and check for command errors.
#     151 if use_cmd:
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1022, in Connection.receive_message(self, request_id)
#    1020     return receive_message(self, request_id, self.max_message_size)
#    1021 except BaseException as error:
# -> 1022     self._raise_connection_failure(error)
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1020, in Connection.receive_message(self, request_id)
#    1015 """Receive a raw BSON message or raise ConnectionFailure.
#    1016
#    1017 If any exception is raised, the socket is closed.
#    1018 """
#    1019 try:
# -> 1020     return receive_message(self, request_id, self.max_message_size)
#    1021 except BaseException as error:
#    1022     self._raise_connection_failure(error)
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\network.py:257, in receive_message(conn, request_id, max_message_size)
#     255         deadline = None
#     256 # Ignore the response's request id.
# --> 257 length, _, response_to, op_code = _UNPACK_HEADER(_receive_data_on_socket(conn, 16, deadline))
#     258 # No request_id for exhaust cursor "getMore".
#     259 if request_id is not None:
#
# File c:\Users\vae.tiolamon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\network.py:340, in _receive_data_on_socket(conn, length, deadline)
#     338     if _csot.get_timeout() and deadline is not None:
#     339         conn.set_conn_timeout(max(deadline - time.monotonic(), 0))
# --> 340     chunk_length = conn.conn.recv_into(mv[bytes_read:])
#     341 except BLOCKING_IO_ERRORS:
#     342     raise socket.timeout("timed out") from None
#
# KeyboardInterrupt:
